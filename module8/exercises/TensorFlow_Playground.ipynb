# %% [markdown]
# # Module 8 : Tensor Flow Playground Exercise

# %% [markdown]
# For this exercise, you will focus on interpretation and understanding of neural network behavior in the context of:
#  1. Input (Data)
#  1. Architecture
#  1. Activation Functions
#  1. Resulting Decision Planes
#  1. Hyper-parameter Tuning
#
# The link below should open the TensorFlow NN Playground to the simple data set.
#
# ![TFPG_DS_2_blobs.png MISSING](../images/TFPG_DS_2_blobs.png)
#
# [Access the TensorFlow Playground](https://playground.tensorflow.org/#activation=linear&batchSize=10&dataset=gauss&regDataset=reg-plane&learningRate=0.00001&regularizationRate=0&noise=0&networkShape=1,1&seed=0.44359&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false)

# %% [markdown]
# # Question 1
#
# #### Dataset
#
# ![data](../images/Gaussian-Data.png)
#
# #### Set the hyperparameters as follows:
#  * Learnign Rate : <span style="background:yellow">0.003</span>
#  * Activation : <span style="background:yellow">Linear</span>
#  * Regularization : <span style="background:yellow">None</span>
#  * Regularization Rate : <span style="background:yellow">0</span>
#
#
# **Your hyperparameter bar should like below**
# ![TFPG_HyperParameter_Bar.png MISSING](../images/TFPG_HyperParameter_Bar.png)
#
#
# #### Architecture:
#  Start with a 2 hidden layers, one neuron each, only taking as input $X_1$ and $X_2$.
#
# ![TFPG_E1_Architecture.png MISSING](../images/TFPG_E1_Architecture.png)

# %% [markdown]
# #### Task E1
#   When you are ready, click the play button and watch the model's **training loss**.
#   When the loss reaches 0.0, pause the training (clicking the button again).
#
#   The result should look similar to:
#
#   ![TFPG_E1_sample_output.png](../images/TFPG_E1_sample_output.png)
#
#   **Q**: How many epochs did you need to get the training loss down to 0.0?

# %% [raw]
# # E1: Write your Answer Below
# # ----------------------------
#
#
# 484

# %% [markdown]
# #### Capture a screen shot of your trained model, upload the screenshot, and embed it
#
# **In this Cell, Double Click**, then Adjust the file name at the bottom image markdown after you upload it to the `module8/exercises` folder
#  * For example, you may need to adjust the file extension.
#
# ```
# ![Screenshot_1.png MISSING](./Screenshot_1.png) --> (./M8_E1_image.jpeg)
# ```
#
# ![Screenshot_1.png](./<givefilepathhere>.png)

# %% [markdown]
# ![title]("Screenshot_1.png")![Screenshot_1.png](attachment:Screenshot_1.png)--> (./M8_E1_image.jpeg)

# %% [markdown]
# ----
#
# # Question 2
#
# #### Set the hyperparameters as follows:
#  * Learnign Rate : <span style="background:yellow">0.003</span>
#  * **Activation** : <span style="background:yellow">Sigmoid</span>
#  * Regularization : <span style="background:yellow">None</span>
#  * Regularization Rate : <span style="background:yellow">0</span>
#
#
# #### Architecture:
#  * Input : Only $X_1$ and $X_2$
#  * 1 first hidden layer neuron
#  * 1 second hidden layer neuron
#
#
# #### Task E2:
#   When you are ready, click the play button and watch the model's **training loss**.
#   When the loss reaches 0.0, pause the training (clicking the button again).
#
#   **Q**: What is a difference you observe just by changing the activation function?

# %% [raw]
# # E2 Write your Answer Below
# # ----------------------------
#
#
# Traning loss took a lot longer to reach 0, and the amount of Epoch it took to reach 0 was well over 10,000! Sigmoid, if I'm understanding correctly, just views all inputs as 0s and 1s (binary) so decisions take a longer time to learn!

# %% [markdown]
# ----
#
# # Question 3
#
# ## Change to Four-Quadrant Data Set
#
# ![TFPG_4_Quad_DS.png MISSING](../images/TFPG_4_Quad_DS.png)
#
# #### Set the hyperparameters as follows:
#  * Learnign Rate : <span style="background:yellow">0.003</span>
#  * **Activation** : <span style="background:yellow">Linear</span>
#  * Regularization : <span style="background:yellow">None</span>
#  * Regularization Rate : <span style="background:yellow">0</span>
#
#
# #### Architecture:
#  * Input : Only $X_1$ and $X_2$
#  * 1 first hidden layer neuron
#  * 1 second hidden layer neuron
#
# #### Task E3:
#   When you are ready, click the play button and watch the model's **training loss**.
#   Let training run for 3,000 epochs.
#
#   **Q**: Based on your readings and the videos, why did the NN not converge to near zero loss?

# %% [raw]
# # E3 Write your Answer Below
# # ----------------------------
#
# The model is not learning due to lack of info coming from the data or limited capacity of the model. If we adjust the feaures to X1X2 and continue to keep 2 hidden layers, our model learns much faster.
#
# In particular, it's problematic that we are using a Linear Activation with X1 and X2 inputs given that the data is not linear. When using linear activation, back propagation is limited. No matter how you add up linear functions, the results would still be linear. Meaning that if the data is non-linear, this is not the right choice.

# %% [markdown]
# ----
#
# # Question 4
#
# You will now adjust the activation type and the number of hidden layers to build a good classifier.
# Please keep track of what you try and log the efforts (Activation Fuction, Neuron Architecture, Final Loss, Epochs of training).
#
# **Constraint:** Try to keep the learning rate at 0.003 and only use the inputs $X_1$ and $X_2$.
#
# **Goal:** Get the training loss below 0.01; if you can down to 0.001.
#
# **Capture:** A screen shot of your final trained model.
#
#
# #### Set the hyperparameters as follows:
#  * Learnign Rate : <span style="background:yellow">0.003</span>
#  * **Activation** : <span style="background:yellow"> Experiment</span>
#  * Regularization : <span style="background:yellow">None</span>
#  * Regularization Rate : <span style="background:yellow">0</span>
#
#
# #### Architecture:
#  * Input : Only $X_1$ and $X_2$
#  * <span style="background:yellow"> Experiment with </span> hidden layers
#
#
# #### Task E4:
#
# **For each architecture you evaluated**
#  * **Q**: Describe your final architecture
#  * **Q**: Detail your hyperparameters
#  * **Q**: How many epochs, and what was your final loss
#
# **Final Q**: What are you take-aways you have from this exercise in regards to architecture versus decision surfaces?

# %% [raw]
# # E4 Write your Answer Below
# # ----------------------------
# Method 1 -
# Activation - Tanh
# Two hidden Layers
# 	first hidden layer = 6 neurons
# 	second hidden layer = 4 neurons
# epoch = 2,886 / final loss = .001
#
# Method 2 -
# Activation - Tanh
# Two Hidden Layers
# 	first hidden layer = 7 neurons
# 	second hidden layer = 5 neurons
# epoch = 2,397 / total loss = .001
#
# Method 3
# Activation - Tanh
# Four hidden layers
# 	first hidden layer = 6 neurons
# 	second hidden layer = 4 neurons
# 	third hidden layer = 2 nuerons
# 	fourth hidden layer = 3 neurons
# epoch - 1,400 / total loss = .001
#
# Method 4
# Activation ReLu
# 3 Hidden Layers
# 	first hidden layer - 4 neurons
# 	second hidden layer - 2 neurons
# 	third hidden layer - 1 nueron
# epoch = 1,404 / total loss = .001
#
# Method 5 BEST NETWORK
# Activation - ReLu
# 3 hidden layers
# 	first hidden layer = 4 neurons
# 	second hidden layer = 2 neurons
# 	third hidden layer = 2 neurons
# epoch = 731 / total loss = .001
#
# Throughout a lot of experimentation, it became increasingly relevant that the number of neurons used in one layer combine knowledge to reach a deicion. Sometimes, the same result can be had from one layer and many nuerons vs few nerurons and more layers. Increasing layers as opposed to increasing more nuerons often allowed for faster learning. When data is non linear such as this, increasing the numbr of layers and using Tanh and ReLu activation yielded the best results.

# %% [markdown]
# #### Capture a screen shot of your final trained model and embed it
#
#
# ![E4_image.png](attachment:E4_image.png)--> (./M8_E4_image.jpeg)

# %% [markdown]
# ----
#
# # Question 5
#
# Using the Architecture you found as best above, change data sets to the enclosing configuration.
#
# ![TFPG_Enclosed_DS.png MISSING](../images/TFPG_Enclosed_DS.png)
#
# #### Set the hyperparameters as follows:
# **<span style="background:yellow">Experiment</span>**
#
#
# #### Architecture:
# **<span style="background:yellow">Locked to Final Architecture of Exercise Question 4.</span>**
#
#
# #### Task E5
#
#   **Q**: Provide a detailed assessment of what you observed and any changes you made to the hyper parameters.
#  Pay special attention to discussion of the results decision surfaces, error, and epohcs.

# %% [raw]
# # E5 Write your Answer Below
# # ----------------------------
#
# I was actually able to keep everything the same as my best model above... so
# Learning Rate - .003
# Activation - ReLu
# Regularization - none
# regularzation rate - 0
# 3 hidden layers
# 	first hidden layer = 4 neurons
# 	second hidden layer = 2 neurons
# 	third hidden layer = 2 neurons
# epoch = 224 / total loss = .001
#
#
#
# by 48 epoch, the model has already captured the general shape of the data. Quite impressive! It looks like the last hidden layer is priamrily reponsible for the network recognizing the blue data points tend to be in the middle

# %% [markdown]
# #### Capture a screen shot of your trained model and embed it
#
#
# ![E5__image.png](attachment:E5__image.png) --> (./M8_E5_image.jpeg)

# %% [markdown]
# ----
#
# # M5 Exercise Question 6
#
# **Starting** with the Architecture you found as best in Exercise Q6, change data sets to the spiral configuration.
#
# ![TFPG_Enclosed_DS.png MISSING](../images/TFPG_Spiral_DS.png)
#
#
# #### Set the hyperparameters as follows:
# **<span style="background:yellow">Experiment</span>**
#
# #### Architecture:
# **<span style="background:yellow">Locked to Final Architecture of Exercise Question 4.</span>**
#
#
# #### Task E6
#   Your goal is the get the lowest training and testing loss with the fewest epochs.
#   Do what ever it takes!
#
#   **Q**: Describe your "fun" with this question!

# %% [raw]
# # E6 Write your Answer Below
# # ----------------------------
#
# Learning Rate - ReLu
# Activation - ReLu
# Regularization - none
# regularzation rate - 0
# 3 hidden layers
# 	first hidden layer = 4 neurons
# 	second hidden layer = 2 neurons
# 	third hidden layer = 2 neurons
#
#
# The network struggles to learn given the architecture and hyperparameters listed above. At 2,500 epoch training loss is still only .372. I'll start playing around and seeing what I can do. Looking at the patterns on the neurons displayed now gives no indication that the network is learning anywhere close to the spiral pattern.
#
# Learning Rate - .003
# Activation - ReLu
# Regularization - none
# regularzation rate - 0
# 3 hidden layers
# 	first hidden layer = 6 neurons
# 	second hidden layer = 2 neurons
# 	third hidden layer = 2 neurons
#
# at 2500 epoch loss is .427
#
#
# Learning Rate - .003
# Activation - ReLu
# Regularization - none
# regularzation rate - 0
# 3 hidden layers
# 	first hidden layer = 6 neurons
# 	second hidden layer = 4 neurons
# 	third hidden layer = 3 neurons
#  epoch = 1,148 / total loss = .023
#
#  display is closer to a spiral pattern!
#
#
# Learning Rate - .003
# Activation - ReLu
# Regularization - none
# regularzation rate - 0
# 4 hidden layers
# 	first hidden layer = 6 neurons
# 	second hidden layer = 4 neurons
# 	third hidden layer = 3 neurons
#     fourth - 3 neurons
#   762 epoch / trainng loss = .057
#
#
#  BEST FUNCTIONING
#
# Learning Rate - .003
# Activation - ReLu
# Regularization - none
# regularzation rate - 0
# 4 hidden layers
# 	first hidden layer = 6 neurons
# 	second hidden layer = 3 neurons
# 	third hidden layer = 4 neurons
#     fourth - 2 neurons
#   1,834 epoch / trainng loss = .008
#
#
#
#  When the model was trying to learn this pattern porperly, there were many times were the model would also unlearn, and training loss would increase. This made it harder to judge how the network was actually performing. In additon, my network kept wanting to think that the top was orange, and the bottom was blue, because of the higher prevelance of oranges on top and blues on the bottom, I found that adding more neurons in deeper hidden layers helped the model realize this was the incorrect pattern. NN's require a lot of exiperimentation!!

# %% [markdown]
# #### Capture a screen shot that includes data set, hyperparameters, architecture, and results model (decision surfaces).
#
# ![E6_image.png](attachment:E6_image.png) --> (./M8_E5_image.jpeg)

# %% [markdown]
# # Save your notebook, then `File > Close and Halt`
